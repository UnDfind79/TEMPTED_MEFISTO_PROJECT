# %% [markdown]
# # 06 — TEMPTED–MEFISTO analysis and plots
#
# **Input:** the two full fitted models, the post-method evaluation, and preprocessing metadata/taxonomy
# **Does:** creates final country-focused comparison figures, metadata summaries, latent-space plots, loading plots, and taxonomy ring charts
# **Output:** figures and summary tables under `data/figures/<timestamp>/`
#
# The focus here is **country-discriminative structure**: how strongly FIN, EST, and RUS are separated and encoded in the latent representations.

# %%
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
from matplotlib import cm, colors
import numpy as np
import pandas as pd
from scipy.stats import kruskal
from sklearn.metrics import confusion_matrix

COUNTRIES = ["FIN", "EST", "RUS"]
COLORS = {"FIN": "#0072B2", "EST": "#009E73", "RUS": "#D55E00"}
TOP_N_LOADINGS = 10
MAX_RING_FEATURES = 48

root = Path(".") if Path("data").exists() else Path("..")
preprocess_folder = sorted((root / "data" / "preprocessing").iterdir())[-1]
evaluation_folder = sorted((root / "data" / "evaluation").iterdir())[-1]
tempted_folder = sorted((root / "data" / "tempted").iterdir())[-1]
mefisto_folder = sorted((root / "data" / "mefisto").iterdir())[-1]
run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
output = root / "data" / "figures" / run_id
output.mkdir(parents=True, exist_ok=True)

metadata = pd.read_csv(preprocess_folder / "metadata.csv", dtype={"sample_id": str, "subject_id": str, "country": str})
coordinates = pd.read_csv(preprocess_folder / "coordinates.csv", dtype={"sample_id": str, "subject_id": str, "country": str})
taxonomy = pd.read_csv(preprocess_folder / "taxonomy.csv")
metrics = pd.read_csv(evaluation_folder / "metrics.csv")
predictions = pd.read_csv(evaluation_folder / "predictions.csv", dtype={"subject_id": str})
country_recall = pd.read_csv(evaluation_folder / "per_country_recall.csv")
tempted = pd.read_csv(tempted_folder / "subject_scores.csv", dtype={"subject_id": str, "country": str})
tempted_loadings = pd.read_csv(tempted_folder / "feature_loadings.csv")
mefisto = pd.read_csv(mefisto_folder / "subject_scores.csv", dtype={"subject_id": str, "country": str})
mefisto_loadings = pd.read_csv(mefisto_folder / "feature_loadings.csv")
mefisto_samples = pd.read_csv(mefisto_folder / "sample_factors.csv", dtype={"sample_id": str, "subject_id": str, "country": str})

tempted_columns = [c for c in tempted.columns if c.startswith("component_")]
mefisto_columns = [c for c in mefisto.columns if c.startswith("factor_")]

taxonomy = taxonomy.rename(columns={taxonomy.columns[0]: "feature"}) if taxonomy.columns[0] != "feature" else taxonomy
print("Preprocessing:", preprocess_folder)
print("Evaluation:", evaluation_folder)
print("Figures:", output)
print("TEMPTED dimensions:", len(tempted_columns))
print("MEFISTO dimensions:", len(mefisto_columns))

# %%
def save(name):
    plt.tight_layout()
    plt.savefig(output / name, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close()

def short_name(x):
    return str(x).split("|")[-1].replace("g__", "")

def z_columns(frame, columns):
    out = frame[["subject_id", "country"] + columns].copy()
    out[columns] = (out[columns] - out[columns].mean()) / out[columns].std(ddof=0).replace(0, 1)
    return out

def country_tests(frame, columns, method):
    rows = []
    z = z_columns(frame, columns)
    means = z.groupby("country")[columns].mean().reindex(COUNTRIES)
    for column in columns:
        groups = [z.loc[z["country"] == c, column].dropna().to_numpy() for c in COUNTRIES]
        stat, p = kruskal(*groups)
        country_means = means[column]
        rows.append({
            "method": method,
            "dimension": column,
            "kruskal_statistic": stat,
            "p_value": p,
            "neg_log10_p": -np.log10(max(p, 1e-300)),
            "FIN_mean_z": country_means.get("FIN", np.nan),
            "EST_mean_z": country_means.get("EST", np.nan),
            "RUS_mean_z": country_means.get("RUS", np.nan),
            "max_minus_min_mean_z": country_means.max() - country_means.min(),
        })
    return pd.DataFrame(rows), means

def ring_chart(loadings, columns, method, filename):
    table = loadings.copy()
    first = table.columns[0]
    if first != "feature_id":
        table = table.rename(columns={first: "feature_id"})
    table = table.merge(taxonomy, left_on="feature_id", right_on="feature", how="left")
    table["genus_label"] = table["feature_id"].map(short_name)
    table["importance"] = table[columns].abs().max(axis=1)
    if len(table) > MAX_RING_FEATURES:
        table = table.nlargest(MAX_RING_FEATURES, "importance")
    order_cols = [c for c in ["phylum", "class", "order", "family", "genus_label"] if c in table.columns]
    table = table.sort_values(order_cols + ["feature_id"]).reset_index(drop=True)

    values = table[columns].to_numpy(float)
    vmax = np.nanmax(np.abs(values))
    vmax = 1 if not np.isfinite(vmax) or vmax == 0 else vmax
    norm = colors.TwoSlopeNorm(vmin=-vmax, vcenter=0, vmax=vmax)
    cmap = cm.get_cmap("coolwarm")

    n_features = len(table)
    n_rings = len(columns)
    width = 2 * np.pi / n_features
    angles = np.arange(n_features) * width

    fig = plt.figure(figsize=(11, 11))
    ax = plt.subplot(111, projection="polar")
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_ylim(0, n_rings + 2.8)

    for ring_index, column in enumerate(columns):
        bottom = ring_index + 0.5
        for feature_index, angle in enumerate(angles):
            value = values[feature_index, ring_index]
            ax.bar(angle, 1.0, width=width * 0.98, bottom=bottom, align="edge",
                   color=cmap(norm(value)), edgecolor="white", linewidth=0.3)

    for feature_index, angle in enumerate(angles):
        theta = angle + width / 2
        label = table.loc[feature_index, "genus_label"]
        rotation = np.degrees(theta)
        if 90 < rotation < 270:
            rotation += 180
            ha = "right"
        else:
            ha = "left"
        ax.text(theta, n_rings + 1.0, label, rotation=rotation - 90,
                rotation_mode="anchor", ha=ha, va="center", fontsize=7)

    if "phylum" in table.columns:
        groups = table.groupby("phylum", dropna=False).indices
        for phylum, idx in groups.items():
            start = min(idx)
            end = max(idx) + 1
            ax.plot([angles[start], angles[start]], [0.4, n_rings + 0.8], color="black", linewidth=0.6, alpha=0.6)
            center = (angles[start] + angles[end - 1] + width) / 2
            if end - start > 1:
                rotation = np.degrees(center)
                if 90 < rotation < 270:
                    rotation += 180
                    ha = "right"
                else:
                    ha = "left"
                ax.text(center, n_rings + 2.1, str(phylum).replace("p__", ""), rotation=rotation - 90,
                        rotation_mode="anchor", ha=ha, va="center", fontsize=8, fontweight="bold")

    mappable = cm.ScalarMappable(norm=norm, cmap=cmap)
    cbar = plt.colorbar(mappable, ax=ax, pad=0.08, fraction=0.04)
    cbar.set_label("Loading")
    fig.text(0.5, 0.03, "Rings go from inner to outer in this order: " + ", ".join(columns), ha="center", fontsize=9)
    plt.title(f"{method} taxonomy ring chart")
    save(filename)

# %% [markdown]
# ## Country and metadata summaries

# %%
visits = metadata.groupby(["subject_id", "country"]).size().rename("visits").reset_index()
country_summary = (
    metadata.groupby("country")
    .agg(
        samples=("sample_id", "count"),
        subjects=("subject_id", pd.Series.nunique),
        mean_age=("age", "mean"),
        median_age=("age", "median"),
        mean_library_size=("library_size", "mean"),
    )
    .reindex(COUNTRIES)
    .reset_index()
)
country_summary.to_csv(output / "country_summary.csv", index=False)

country_summary

# %%
country_summary.set_index("country")[["samples", "subjects"]].plot.bar(color=[COLORS[c] for c in COUNTRIES])
plt.ylabel("Count")
plt.title("Samples and subjects by country")
save("country_counts.png")

plt.boxplot([metadata.loc[metadata["country"] == c, "age"].dropna() for c in COUNTRIES], labels=COUNTRIES)
plt.ylabel("Age at collection")
plt.title("Age by country")
save("country_age_boxplot.png")

plt.boxplot([visits.loc[visits["country"] == c, "visits"].dropna() for c in COUNTRIES], labels=COUNTRIES)
plt.ylabel("Samples per subject")
plt.title("Longitudinal sampling depth by country")
save("country_visits_boxplot.png")

for country in COUNTRIES:
    rows = coordinates["country"] == country
    plt.scatter(coordinates.loc[rows, "tsne_1"], coordinates.loc[rows, "tsne_2"], s=15, alpha=0.7,
                label=country, color=COLORS[country])
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("Preprocessing t-SNE by country")
plt.legend(frameon=False)
save("preprocessing_tsne_country.png")

# %% [markdown]
# ## Held-out classifier performance

# %%
balanced = metrics.pivot(index="split", columns="method", values="balanced_accuracy")

plt.plot(balanced.index, balanced["TEMPTED"], marker="o", label="TEMPTED")
plt.plot(balanced.index, balanced["MEFISTO"], marker="o", label="MEFISTO")
plt.xlabel("Split")
plt.ylabel("Balanced accuracy")
plt.title("Balanced accuracy by split")
plt.legend(frameon=False)
save("balanced_accuracy_by_split.png")

plt.boxplot([
    metrics.loc[metrics["method"] == "TEMPTED", "balanced_accuracy"],
    metrics.loc[metrics["method"] == "MEFISTO", "balanced_accuracy"],
], labels=["TEMPTED", "MEFISTO"])
plt.ylabel("Balanced accuracy")
plt.title("Balanced accuracy distribution")
save("balanced_accuracy_boxplot.png")

difference = balanced["TEMPTED"] - balanced["MEFISTO"]
plt.axhline(0, color="black", linewidth=1)
plt.bar(difference.index, difference.values)
plt.xlabel("Split")
plt.ylabel("TEMPTED - MEFISTO")
plt.title("Balanced accuracy difference")
save("balanced_accuracy_difference.png")

pivot = country_recall.pivot_table(index="country", columns="method", values="recall", aggfunc="mean").reindex(COUNTRIES)
pivot.to_csv(output / "country_recall_summary.csv")
pivot.plot.bar(color=["#4C72B0", "#DD8452"])
plt.ylabel("Mean recall")
plt.title("Per-country recall")
save("country_recall.png")

# %%
for method in ["TEMPTED", "MEFISTO"]:
    rows = predictions[predictions["method"] == method]
    matrix = confusion_matrix(rows["truth"], rows["predicted"], labels=COUNTRIES, normalize="true")

    plt.imshow(matrix, vmin=0, vmax=1, cmap="Blues")
    plt.colorbar(label="Fraction")
    plt.xticks(range(len(COUNTRIES)), COUNTRIES)
    plt.yticks(range(len(COUNTRIES)), COUNTRIES)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"{method} confusion matrix")
    for i in range(len(COUNTRIES)):
        for j in range(len(COUNTRIES)):
            plt.text(j, i, f"{matrix[i, j]:.2f}", ha="center", va="center")
    save(f"{method.lower()}_confusion_matrix.png")

# %% [markdown]
# ## Country structure in the latent spaces
#
# The figures below are designed to work with any number of components or factors.

# %%
for method, scores, columns in [
    ("TEMPTED", tempted, tempted_columns),
    ("MEFISTO", mefisto, mefisto_columns),
]:
    tests, means = country_tests(scores, columns, method)
    tests.to_csv(output / f"{method.lower()}_country_tests.csv", index=False)
    means.to_csv(output / f"{method.lower()}_country_means.csv")

    plt.figure(figsize=(max(6, len(columns) * 0.8), 3.5))
    plt.imshow(means.to_numpy(float), aspect="auto", cmap="coolwarm")
    plt.colorbar(label="Mean z-score")
    plt.xticks(range(len(columns)), columns, rotation=45, ha="right")
    plt.yticks(range(len(COUNTRIES)), COUNTRIES)
    plt.title(f"{method} country means by dimension")
    save(f"{method.lower()}_country_means_heatmap.png")

    plt.figure(figsize=(max(6, len(columns) * 0.8), 3.5))
    plt.bar(range(len(columns)), tests["neg_log10_p"].values)
    plt.xticks(range(len(columns)), columns, rotation=45, ha="right")
    plt.ylabel("-log10 Kruskal-Wallis p")
    plt.title(f"{method} country association by dimension")
    save(f"{method.lower()}_country_tests.png")

    if len(columns) >= 2:
        xcol, ycol = columns[:2]
        for country in COUNTRIES:
            rows = scores["country"] == country
            plt.scatter(scores.loc[rows, xcol], scores.loc[rows, ycol], s=28, alpha=0.75,
                        label=country, color=COLORS[country])
        plt.xlabel(xcol)
        plt.ylabel(ycol)
        plt.title(f"{method} latent space")
        plt.legend(frameon=False)
        save(f"{method.lower()}_latent_space.png")

    for column in columns:
        plt.boxplot([scores.loc[scores["country"] == c, column].dropna() for c in COUNTRIES], labels=COUNTRIES)
        for i, country in enumerate(COUNTRIES, start=1):
            y = scores.loc[scores["country"] == country, column].dropna().to_numpy()
            x = np.random.normal(i, 0.04, size=len(y))
            plt.scatter(x, y, s=10, alpha=0.4, color=COLORS[country])
        plt.ylabel(column)
        plt.title(f"{method} {column} by country")
        save(f"{method.lower()}_{column}_country.png")

# %% [markdown]
# ## Age relationships for MEFISTO sample factors
#
# MEFISTO exposes fitted factors for every sample, so their relationship with age can be plotted directly.

# %%
for factor in mefisto_columns:
    for country in COUNTRIES:
        rows = mefisto_samples["country"] == country
        plt.scatter(
            mefisto_samples.loc[rows, "age"],
            mefisto_samples.loc[rows, factor],
            s=12,
            alpha=0.35,
            color=COLORS[country],
            label=country,
        )
    plt.xlabel("Age at collection")
    plt.ylabel(factor)
    plt.title(f"MEFISTO {factor} over age")
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), frameon=False)
    save(f"mefisto_{factor}_age.png")

# %% [markdown]
# ## Genus loadings and taxonomy ring charts

# %%
for method, loadings, columns in [
    ("TEMPTED", tempted_loadings, tempted_columns),
    ("MEFISTO", mefisto_loadings, mefisto_columns),
]:
    ring_chart(loadings, columns, method, f"{method.lower()}_taxonomy_ring_chart.png")

    for column in columns:
        first = loadings.columns[0]
        table = loadings.rename(columns={first: "feature_id"}) if first != "feature_id" else loadings.copy()
        table = table[["feature_id", column]].copy()
        table["absolute"] = table[column].abs()
        top = table.nlargest(TOP_N_LOADINGS, "absolute").sort_values(column)
        labels = [short_name(x) for x in top["feature_id"]]
        plt.barh(labels, top[column].values)
        plt.xlabel("Loading")
        plt.title(f"{method} {column} top genera")
        save(f"{method.lower()}_{column}_top_loadings.png")

# %% [markdown]
# ## Cross-method loading correlations
#
# This is a simple correlation table between every TEMPTED component and every MEFISTO factor.

# %%
shared = tempted_loadings.merge(mefisto_loadings, on="feature_id", suffixes=("_tempted", "_mefisto"))
correlations = np.full((len(tempted_columns), len(mefisto_columns)), np.nan)

for i, component in enumerate(tempted_columns):
    for j, factor in enumerate(mefisto_columns):
        correlations[i, j] = np.corrcoef(shared[component], shared[factor])[0, 1]

correlation_table = pd.DataFrame(correlations, index=tempted_columns, columns=mefisto_columns)
correlation_table.to_csv(output / "loading_correlations.csv")

plt.figure(figsize=(max(5, len(mefisto_columns) * 0.8), max(4, len(tempted_columns) * 0.8)))
plt.imshow(correlations, vmin=-1, vmax=1, cmap="coolwarm")
plt.colorbar(label="Correlation")
plt.xticks(range(len(mefisto_columns)), mefisto_columns, rotation=45, ha="right")
plt.yticks(range(len(tempted_columns)), tempted_columns)
plt.title("Cross-method loading correlations")
for i in range(len(tempted_columns)):
    for j in range(len(mefisto_columns)):
        plt.text(j, i, f"{correlations[i, j]:.2f}", ha="center", va="center")
save("loading_correlations.png")

correlation_table
